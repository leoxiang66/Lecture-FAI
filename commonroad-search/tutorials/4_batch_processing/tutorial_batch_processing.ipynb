# %% [markdown]
# # Tutorial: Batch Processing
#
# This tutorial explains how to use the batch processing script to solve CommonRoad planning problems in parallel. The configuration for batch processing is stored in `batch_processing_config.yaml`. Some of the parameters are explained as follows:
# * **input_path**: input directory of your intended CommonRoad scenarios.
# * **output_path**: output directory of CommonRoad solution files.
# * **overwrite**: whether the existing solution files should be overwritten.
# * **validate_solution**: check the validity of the solutions with the feasibility checker.
# * **num_worker_processes**: the number of parallel executions of motion planners.
#
# Parameters specified under the `default` block will be applied to all scenarios. If you wish to specify a different paramter for specific scenarios, simply insert a new block with the content of the `default` block copied, and overwrite parameters therein. This new block should be named after the ID of the sceanrio that you wish to aplly the parameters to. Related parameters are explained as follows:
# * **vehicle_model**: model of the vehicle, valid values: **PM, KS, ST and MB**. Refer to [Vehicle Models](https://gitlab.lrz.de/tum-cps/commonroad-vehicle-models/-/blob/master/vehicleModels_commonRoad.pdf) for more information.
# * **vehicle_type**: type of the vehicle, valid values: **FORD_ESCORT, BMW_320i and VW_VANAGON**.
# * **cost_function**: id of cost function. Refer to [Cost Functions](https://gitlab.lrz.de/tum-cps/commonroad-cost-functions/-/blob/master/costFunctions_commonRoad.pdf) for more information.
# * **planner**: the planner that is used to solve for solutions, possible values are: bfs, dfs, dls, ucs, gbfs, astar, student, student_example
# * **planning_problem_idx**: index of the planning problem. for cooperative scenarios: 0, 1, 2, ..., otherwise: 0
# * **max_tree_depth**: maximum depth of the search tree
# * **timeout**: timeout time for motion planner [s].
#
# Note: the paths can either be **relative** or **absolute**.
# To start the search with batch processing, you can either directly run `SMP/batch_processing/batch_processing_parallel.py` in IDEs (e.g. PyCharm) with `commonroad-search/` marked as sources root, or run the following script.

# %% [markdown]
# ## Parallel Batch Processing
# In parallel batch processing, the search are carried out on multiple threads simultaneously. This reduces the overall time required to test your algorithm on all the given scenarios. One drawback is that it is not very easy to debug your code with parallel batch processing.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

# add the folder containing batch processing script into python path
sys.path.append(os.path.join(os.getcwd(), "../../"))

from SMP.batch_processing.batch_processing_parallel import run_parallel_processing

# %%
run_parallel_processing()
# Out:
# Config file loaded and logger created.
# 18 scenarios skipped.
# ScenarioLoader Mode <DEFAULT>
# Run on all scenarios, except the skipped scenarios
# Number of scenarios: 500
# Automaton loaded for vehicle type: BMW_320i
# Motion planner: student
# Number of parallel processes: 6
#
# ==================================================
# Scenario being processed:	         1
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         2
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         3
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         4
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         5
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         6
# Solution found:               	         0
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         7
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         0
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         8
# Solution found:               	         1
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	         9
# Solution found:               	         2
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        10
# Solution found:               	         3
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        11
# Solution found:               	         4
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        12
# Solution found:               	         5
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        13
# Solution found:               	         6
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        14
# Solution found:               	         7
# Solution found but invalid:   	         0
# Solution not found:           	         1
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        15
# Solution found:               	         7
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        16
# Solution found:               	         8
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        17
# Solution found:               	         9
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        18
# Solution found:               	        10
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        19
# Solution found:               	        11
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        20
# Solution found:               	        12
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        21
# Solution found:               	        13
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        22
# Solution found:               	        14
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        23
# Solution found:               	        15
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# ==================================================
# Scenario being processed:	        24
# Solution found:               	        16
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        25
# Solution found:               	        17
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        26
# Solution found:               	        18
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        27
# Solution found:               	        19
# Solution found but invalid:   	         0
# Solution not found:           	         2
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        28
# Solution found:               	        19
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        29
# Solution found:               	        20
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        30
# Solution found:               	        21
# Solution found but invalid:   	         0
# Solution not found:           	         3
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        31
# Solution found:               	        21
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        32
# Solution found:               	        22
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        33
# Solution found:               	        23
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        34
# Solution found:               	        24
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        35
# Solution found:               	        25
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        36
# Solution found:               	        26
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        37
# Solution found:               	        27
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        38
# Solution found:               	        28
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        39
# Solution found:               	        29
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        40
# Solution found:               	        30
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        41
# Solution found:               	        31
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        42
# Solution found:               	        32
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        43
# Solution found:               	        33
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        44
# Solution found:               	        34
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        45
# Solution found:               	        35
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        46
# Solution found:               	        36
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        47
# Solution found:               	        37
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
# ==================================================
# Scenario being processed:	        48
# Solution found:               	        38
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        49
# Solution found:               	        39
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        50
# Solution found:               	        40
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        51
# Solution found:               	        41
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        52
# Solution found:               	        42
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        53
# Solution found:               	        43
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        54
# Solution found:               	        45
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        55
# Solution found:               	        45
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        56
# Solution found:               	        46
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        57
# Solution found:               	        47
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        58
# Solution found:               	        48
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        59
# Solution found:               	        49
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        60
# Solution found:               	        50
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        61
# Solution found:               	        51
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        62
# Solution found:               	        52
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        63
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         0
# ==================================================
#
# ==================================================
# Scenario being processed:	        64
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         1
# ==================================================
#
# ==================================================
# Scenario being processed:	        65
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         2
# ==================================================
#
# ==================================================
# Scenario being processed:	        66
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         3
# ==================================================
#
# ==================================================
# Scenario being processed:	        67
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         4
# ==================================================
#
# ==================================================
# Scenario being processed:	        68
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         5
# ==================================================
#
# ==================================================
# Scenario being processed:	        69
# Solution found:               	        53
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         6
# ==================================================
#
# ==================================================
# Scenario being processed:	        70
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         6
# ==================================================
#
# ==================================================
# Scenario being processed:	        71
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         7
# ==================================================
# ==================================================
# Scenario being processed:	        72
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         8
# ==================================================
#
# ==================================================
# Scenario being processed:	        73
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	         9
# ==================================================
#
# ==================================================
# Scenario being processed:	        74
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        10
# ==================================================
#
# ==================================================
# Scenario being processed:	        75
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        11
# ==================================================
#
# ==================================================
# Scenario being processed:	        76
# Solution found:               	        54
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        12
# ==================================================
#
# ==================================================
# Scenario being processed:	        77
# Solution found:               	        55
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        12
# ==================================================
#
# ==================================================
# Scenario being processed:	        78
# Solution found:               	        56
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        12
# ==================================================
#
# ==================================================
# Scenario being processed:	        79
# Solution found:               	        57
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        12
# ==================================================
#
# ==================================================
# Scenario being processed:	        80
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        12
# ==================================================
#
# ==================================================
# Scenario being processed:	        81
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        13
# ==================================================
#
# ==================================================
# Scenario being processed:	        82
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        14
# ==================================================
#
# ==================================================
# Scenario being processed:	        83
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        15
# ==================================================
#
# ==================================================
# Scenario being processed:	        84
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        16
# ==================================================
#
# ==================================================
# Scenario being processed:	        85
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        17
# ==================================================
#
# ==================================================
# Scenario being processed:	        86
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        18
# ==================================================
#
# ==================================================
# Scenario being processed:	        87
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        19
# ==================================================
#
# ==================================================
# Scenario being processed:	        88
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        20
# ==================================================
#
# ==================================================
# Scenario being processed:	        89
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        21
# ==================================================
#
# ==================================================
# Scenario being processed:	        90
# Solution found:               	        58
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        22
# ==================================================
#
# ==================================================
# Scenario being processed:	        91
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        22
# ==================================================
#
# ==================================================
# Scenario being processed:	        92
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        23
# ==================================================
#
# ==================================================
# Scenario being processed:	        93
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        24
# ==================================================
#
# ==================================================
# Scenario being processed:	        94
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        25
# ==================================================
#
# ==================================================
# Scenario being processed:	        95
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        26
# ==================================================
# ==================================================
# Scenario being processed:	        96
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        27
# ==================================================
#
# ==================================================
# Scenario being processed:	        97
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        28
# ==================================================
#
# ==================================================
# Scenario being processed:	        98
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        29
# ==================================================
#
# ==================================================
# Scenario being processed:	        99
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        30
# ==================================================
#
# ==================================================
# Scenario being processed:	       100
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        31
# ==================================================
#
# ==================================================
# Scenario being processed:	       101
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        32
# ==================================================
#
# ==================================================
# Scenario being processed:	       102
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        33
# ==================================================
#
# ==================================================
# Scenario being processed:	       103
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        34
# ==================================================
#
# ==================================================
# Scenario being processed:	       104
# Solution found:               	        59
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        35
# ==================================================
#
# ==================================================
# Scenario being processed:	       105
# Solution found:               	        60
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        35
# ==================================================
#
# ==================================================
# Scenario being processed:	       106
# Solution found:               	        61
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        35
# ==================================================
#
# ==================================================
# Scenario being processed:	       107
# Solution found:               	        61
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        36
# ==================================================
#
# ==================================================
# Scenario being processed:	       108
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        36
# ==================================================
#
# ==================================================
# Scenario being processed:	       109
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        37
# ==================================================
#
# ==================================================
# Scenario being processed:	       110
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        38
# ==================================================
#
# ==================================================
# Scenario being processed:	       111
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        39
# ==================================================
#
# ==================================================
# Scenario being processed:	       112
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        40
# ==================================================
#
# ==================================================
# Scenario being processed:	       113
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         4
# Exception occurred:           	         0
# Time out:                     	        41
# ==================================================
#
# ==================================================
# Scenario being processed:	       114
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        41
# ==================================================
#
# ==================================================
# Scenario being processed:	       115
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        42
# ==================================================
#
# ==================================================
# Scenario being processed:	       116
# Solution found:               	        62
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        43
# ==================================================
#
# ==================================================
# Scenario being processed:	       117
# Solution found:               	        63
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        43
# ==================================================
#
# ==================================================
# Scenario being processed:	       118
# Solution found:               	        64
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        43
# ==================================================
#
# ==================================================
# Scenario being processed:	       119
# Solution found:               	        64
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        44
# ==================================================
# ==================================================
# Scenario being processed:	       120
# Solution found:               	        65
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        44
# ==================================================
#
# ==================================================
# Scenario being processed:	       121
# Solution found:               	        65
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        45
# ==================================================
#
# ==================================================
# Scenario being processed:	       122
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        45
# ==================================================
#
# ==================================================
# Scenario being processed:	       123
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        46
# ==================================================
#
# ==================================================
# Scenario being processed:	       124
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        47
# ==================================================
#
# ==================================================
# Scenario being processed:	       125
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        48
# ==================================================
#
# ==================================================
# Scenario being processed:	       126
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        49
# ==================================================
#
# ==================================================
# Scenario being processed:	       127
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        50
# ==================================================
#
# ==================================================
# Scenario being processed:	       128
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        51
# ==================================================
#
# ==================================================
# Scenario being processed:	       129
# Solution found:               	        66
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        52
# ==================================================
#
# ==================================================
# Scenario being processed:	       130
# Solution found:               	        67
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        52
# ==================================================
#
# ==================================================
# Scenario being processed:	       131
# Solution found:               	        68
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        52
# ==================================================
# Something went wrong while processing scenario DEU_Flensburg-81_1_T-1        ]
# Traceback (most recent call last):
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 301, in process_scenario
#     is_valid_solution = save_solution(scenario=scenario, planning_problem_set=planning_problem_set,
#   File "/commonroad/commonroad-search/tutorials/4_batch_processing/../../SMP/batch_processing/process_scenario.py", line 200, in save_solution
#     if valid_solution(scenario, planning_problem_set, solution)[0]:
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 348, in valid_solution
#     starts_at_correct_state(solution, planning_problem_set),
#   File "/opt/conda/lib/python3.9/site-packages/commonroad_dc/feasibility/solution_checker.py", line 314, in starts_at_correct_state
#     raise SolutionCheckerException(msg)
# commonroad_dc.feasibility.solution_checker.SolutionCheckerException: Planning Problem Solution trajectory does not start at the initial_state of the planning problem with ID: 123
# Expected velocity=25.836403
# Received velocity=20.0
#
#
# ==================================================
# Scenario being processed:	       132
# Solution found:               	        68
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        52
# ==================================================
#
# ==================================================
# Scenario being processed:	       133
# Solution found:               	        68
# Solution found but invalid:   	         0
# Solution not found:           	         5
# Exception occurred:           	         0
# Time out:                     	        53
# ==================================================
#
# ...
# Solution found but invalid:   	         0
# Solution not found:           	        10
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       336
# Solution found:               	       205
# Solution found but invalid:   	         0
# Solution not found:           	        10
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       337
# Solution found:               	       206
# Solution found but invalid:   	         0
# Solution not found:           	        10
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       338
# Solution found:               	       206
# Solution found but invalid:   	         0
# Solution not found:           	        11
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       339
# Solution found:               	       207
# Solution found but invalid:   	         0
# Solution not found:           	        11
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       340
# Solution found:               	       207
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       341
# Solution found:               	       208
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       342
# Solution found:               	       209
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       343
# Solution found:               	       210
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       344
# Solution found:               	       211
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       345
# Solution found:               	       212
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       346
# Solution found:               	       213
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       347
# Solution found:               	       214
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       348
# Solution found:               	       215
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       349
# Solution found:               	       216
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       350
# Solution found:               	       217
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       351
# Solution found:               	       218
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       352
# Solution found:               	       219
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       353
# Solution found:               	       220
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       354
# Solution found:               	       221
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       355
# Solution found:               	       222
# Solution found but invalid:   	         0
# Solution not found:           	        12
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       356
# Solution found:               	       222
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
# ==================================================
# Scenario being processed:	       357
# Solution found:               	       223
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       358
# Solution found:               	       224
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       359
# Solution found:               	       225
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       360
# Solution found:               	       226
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       361
# Solution found:               	       227
# Solution found but invalid:   	         0
# Solution not found:           	        13
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       362
# Solution found:               	       227
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       363
# Solution found:               	       228
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       364
# Solution found:               	       229
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       365
# Solution found:               	       230
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       366
# Solution found:               	       231
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       367
# Solution found:               	       232
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       368
# Solution found:               	       233
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       369
# Solution found:               	       234
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       370
# Solution found:               	       235
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       371
# Solution found:               	       236
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       372
# Solution found:               	       237
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       373
# Solution found:               	       238
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       374
# Solution found:               	       239
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       375
# Solution found:               	       240
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       376
# Solution found:               	       241
# Solution found but invalid:   	         0
# Solution not found:           	        14
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       377
# Solution found:               	       241
# Solution found but invalid:   	         0
# Solution not found:           	        15
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       378
# Solution found:               	       242
# Solution found but invalid:   	         0
# Solution not found:           	        15
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       379
# Solution found:               	       243
# Solution found but invalid:   	         0
# Solution not found:           	        15
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================
#
# ==================================================
# Scenario being processed:	       380
# Solution found:               	       244
# Solution found but invalid:   	         0
# Solution not found:           	        15
# Exception occurred:           	         0
# Time out:                     	       114
# ==================================================

# %% [markdown]
# ## Sequential Batch Processing
#
# Alternatively, one can use the `SMP/batch_processing/batch_processing_sequential.py` script to carry out the search sequentially on a single thread. This is a more user-friendly approach if you wish you debug your code in IDES (e.g. creating breakpoints in PyCharm) but still have it run against multiple scenarios.

# %%
# from SMP.batch_processing.batch_processing_sequential import run_sequential_processing
# run_sequential_processing()
